# %%
from scipy import io
import pandas as pd
import numpy as np
import time
import pickle
import os
import h5py
import sys, getopt
import datetime
from io_utils_mod import HDF5Matrix
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
get_ipython().run_line_magic('matplotlib', 'inline')
# from MapCallback import MapCallback

os.environ['CUDA_VISIBLE_DEVICES']='0'

# %%
hdf5path = '../data/all_data.hdf5' # training data generated by loadData.py
# modelName2Save = 'trainModel_InceptionV3_1-v5_bird_tw.h5'

# %%
f = h5py.File(hdf5path, 'r')
X = f.get('X')
y = f.get('y')
print("Shape of X:", X.shape)
dataSetLength = X.shape[0]
output_dim = y.shape[1] #len(y_train[0])
f.close()
print('dataSetLength={}'.format(dataSetLength))
print('output_dim={}'.format(output_dim))

# %%
# print(X)
# Out:
# <Closed HDF5 dataset>

# %%
# keras.utils.io_utils.HDF5Matrix(datapath, dataset, start=0, end=None, normalizer=None)
X = np.array(HDF5Matrix(hdf5path, 'X', 0, dataSetLength))
y = np.array(HDF5Matrix(hdf5path, 'y', 0, dataSetLength))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /opt/conda/lib/python3.6/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     118         try:
# --> 119             fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#     120         except IOError:
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (unable to lock file, errno = 11, error message = 'Resource temporarily unavailable')
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# /opt/conda/lib/python3.6/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     121             try:
# --> 122                 fid = h5f.open(name, h5f.ACC_RDONLY, fapl=fapl)
#     123             except IOError:
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (unable to lock file, errno = 11, error message = 'Resource temporarily unavailable')
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-17-b19376e9dc32> in <module>()
#       1 # keras.utils.io_utils.HDF5Matrix(datapath, dataset, start=0, end=None, normalizer=None)
# ----> 2 X = np.array(HDF5Matrix(hdf5path, 'X', 0, dataSetLength))
#       3 y = np.array(HDF5Matrix(hdf5path, 'y', 0, dataSetLength))
#
# ~/richard/green_light/train/io_utils_mod.py in __init__(self, datapath, dataset, start, end, normalizer)
#      10     def __init__(self, datapath, dataset, start, end, normalizer=None):
#      11         if datapath not in list(self.refs.keys()):
# ---> 12             f = h5py.File(datapath)
#      13             self.refs[datapath] = f
#      14         else:
#
# /opt/conda/lib/python3.6/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, **kwds)
#     267             with phil:
#     268                 fapl = make_fapl(driver, libver, **kwds)
# --> 269                 fid = make_fid(name, mode, userblock_size, fapl, swmr=swmr)
#     270
#     271                 if swmr_support:
#
# /opt/conda/lib/python3.6/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     122                 fid = h5f.open(name, h5f.ACC_RDONLY, fapl=fapl)
#     123             except IOError:
# --> 124                 fid = h5f.create(name, h5f.ACC_EXCL, fapl=fapl, fcpl=fcpl)
#     125     else:
#     126         raise ValueError("Invalid mode; must be one of r, r+, w, w-, x, a")
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.create()
#
# OSError: Unable to create file (unable to open file: name = '../data/all_data.hdf5', errno = 17, error message = 'File exists', flags = 15, o_flags = c2)
