# %%
import os#!/usr/bin/python
# -*- coding: UTF-8 -*-

import os, sys
import numpy as np

# %%
os.getcwd()
# Out:
# 'D:\\AIA\\AIAcode\\birdsong-keras\\preprocess'

# %%
# 打开文件
path = "D:\\合併學名後\\"
Fstdirs = os.listdir(path)
# Fstdirs = Fstdirs[2:]
Snddirs = []
# 输出所有文件和文件夹
for file in Fstdirs:
#     print('aaaaaaaaaaaaaaaaaaaaaaaaaaaaa')
    tmpdir = []
    tmpdir = os.listdir(path + file)
    for fname in tmpdir:
        print(path + file + '\\' + fname ) #,  path + file + '_' + fname)
#         os.rename(path + file + '\\' + fname , path + file + '_' + fname)
#         Snddirs = Snddirs + [file+'_'+fname]
#     print(tmpdir)
#    print(file)
# np.count_nonzero(Snddirs)
# print(Snddirs)
# Out:
# D:\合併學名後\all_forg_mp3\中國樹蟾 Hyla chinensis_13496767241evk-l.mp3
# D:\合併學名後\all_forg_mp3\中國樹蟾 Hyla chinensis_13496768331j46-l.mp3
# D:\合併學名後\all_forg_mp3\中國樹蟾 Hyla chinensis_13497525721wn4-l.mp3
# D:\合併學名後\all_forg_mp3\中國樹蟾 Hyla chinensis_134975265413jl-l.mp3
# D:\合併學名後\all_forg_mp3\中國樹蟾 Hyla chinensis_Hyla_chinensis.mp3
# D:\合併學名後\all_forg_mp3\中國樹蟾 Hyla chinensis_中國樹蟾鳴叫2 - YouTube (480p).mp3
# D:\合併學名後\all_forg_mp3\中國樹蟾 Hyla chinensis_五一五二..半夜蛙鳴 中國樹蟾 吵翻天 - YouTube (480p).mp3
# D:\合併學名後\all_forg_mp3\中國樹蟾 Hyla chinensis_可愛的翠綠中國樹蟾，怕吵請先將音量調小 - YouTube (720p).mp3
# D:\合併學名後\all_forg_mp3\亞洲錦蛙 Kaloula pulchra_13729212331ufi-l.mp3
# D:\合併學名後\all_forg_mp3\亞洲錦蛙 Kaloula pulchra_13783673301zid-l.mp3
# D:\合併學名後\all_forg_mp3\亞洲錦蛙 Kaloula pulchra_1383189065183d-l.mp3
# D:\合併學名後\all_forg_mp3\亞洲錦蛙 Kaloula pulchra_138683223018rt-l.mp3
# D:\合併學名後\all_forg_mp3\古氏赤蛙 Rana kuhlii (Limnonectes fujianensis？？？)_國家公園行動圖鑑 A0012s001.mp3
# D:\合併學名後\all_forg_mp3\台北樹蛙 Rhacophorus taipeianus_13417410181pdd-l.mp3
# ...
